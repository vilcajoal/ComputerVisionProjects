# %% [markdown]
# <table>
#   <tr><td>
#   </td></tr>
#   <tr><td align="center">
#     <b>Introducción al procesamiento de imagenes con Python y Opencv
#   </td></tr>
# </table>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./img/bananos.jpg')

# %%
img.shape
# Out:
# (900, 1200, 3)

# %%
plt.imshow(img)

# %%
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)

# %%
plt.imshow(hsv)

# %%
I = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(I)

# %%
umbral = 251

# %%
mascara = np.uint8((I<200)*255)

# %%
dato = I.flatten()

# %%
plt.imshow(mascara)

# %%
rojo = img[:,:,0].flatten()
verde = img[:,:,1].flatten()
azul = img[:,:,2].flatten()

# %%
# Histograma de colores en una imagen
plt.hist(rojo, bins = 1000, histtype='stepfilled', color = 'r', range=(0,254))
plt.hist(verde, bins = 1000, histtype='stepfilled', color = 'g', range=(0,254))
plt.hist(azul, bins = 1000, histtype='stepfilled', color = 'b', range=(0,254))
plt.show()

# %%
img = cv2.imread('./img/000078.jpg')

# %%
umbral, _ = cv2.threshold(I, 0, 255, cv2.THRESH_OTSU)

# %%
plt.imshow(img)

# %%
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)

# %%
plt.imshow(hsv)

# %%
I = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(I)

# %%
mascara = np.uint8((I<umbral)*255)

# %%
cv2.imshow('imagen', mascara)
cv2.waitKey(0)
cv2.destryAllWindows(w)
